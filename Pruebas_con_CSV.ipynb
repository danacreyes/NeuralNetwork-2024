# %%
#mlp = MLPClassifier(hidden_layer_sizes=(64,32), max_iter=80, activation='relu',
#                    solver='sgd', verbose=1, random_state=42,                      #Precisión del modelo: 97.16%
#                    learning_rate_init=0.02, batch_size=100)

#mlp = MLPClassifier(hidden_layer_sizes=(64,32), max_iter=80, activation='relu',
#                    solver='sgd', verbose=1, random_state=42,                       #Precisión del modelo: 96.58%
#                    learning_rate_init=0.01, batch_size=200)

#mlp = MLPClassifier(hidden_layer_sizes=(64,32), max_iter=80, activation='relu',
#                    solver='sgd', verbose=1, random_state=42,                       #Precisión del modelo: 96.86%
#                    learning_rate_init=0.03, batch_size=200)

#mlp = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=600, activation='relu',
#                    solver='sgd', verbose=1, random_state=43,                       #Precisión del modelo: 96.99% pero le pego a todas las imagenes que hice
#                    learning_rate_init=0.001, batch_size=128)

#mlp = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=600, activation='relu',
#                    solver='sgd', verbose=1, random_state=42,                      #Precisión del modelo: 97.15% pero le pego a todas las imagenes que hice
#                    learning_rate_init=0.001, batch_size=128)



# TENES QUE CENTRAR LAS IMAGENES PARA QUE FUNCIONE BIEN PRIORIZA OTRRAS COSAS (estan normalizadas en 20x20 eso ocupan las imagenes y despues se les agrega 4 pixeles en todas las direcciones y llega a 28x28)
#   https://interactivechaos.com/es/manual/tutorial-de-deep-learning/el-dataset-mnist
# Fijate con alguna libreia de pytohn para hacer un display de pantalla para que escriba alguien lo numeros en vez de hacerlo en paint
# Cuales son los requisitos para que detecte bien la imagen?

from data import get_minst


# INTENTAR HACER QUE CALCULE EN TIEMPO REAL QUE NUMERO ES UNA ONDA ASI:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

data = pd.read_csv('DATA/train.csv')

X, Y = data.iloc[:, 1:].values, data.iloc[:, 0].values
X = X / 255.0

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

mlp = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=600, activation='relu',
                    solver='sgd', verbose=1, random_state=42,
                    learning_rate_init=0.001, batch_size=128)

mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo: {accuracy * 100:.2f}%')
# Out:
# Iteration 1, loss = 1.76826214
# Iteration 2, loss = 0.84457665
# Iteration 3, loss = 0.56282424
# Iteration 4, loss = 0.46147574
# Iteration 5, loss = 0.40829075
# Iteration 6, loss = 0.37475040
# Iteration 7, loss = 0.35068872
# Iteration 8, loss = 0.33217779
# Iteration 9, loss = 0.31697176
# Iteration 10, loss = 0.30430830
# Iteration 11, loss = 0.29285762
# Iteration 12, loss = 0.28343386
# Iteration 13, loss = 0.27439511
# Iteration 14, loss = 0.26608249
# Iteration 15, loss = 0.25875266
# Iteration 16, loss = 0.25162493
# Iteration 17, loss = 0.24546437
# Iteration 18, loss = 0.23932017
# Iteration 19, loss = 0.23358365
# Iteration 20, loss = 0.22787553
# Iteration 21, loss = 0.22263344
# Iteration 22, loss = 0.21790300
# Iteration 23, loss = 0.21269094
# Iteration 24, loss = 0.20828689
# Iteration 25, loss = 0.20424942
# Iteration 26, loss = 0.19976015
# Iteration 27, loss = 0.19590877
# Iteration 28, loss = 0.19176315
# Iteration 29, loss = 0.18764533
# Iteration 30, loss = 0.18445766
# Iteration 31, loss = 0.18057941
# Iteration 32, loss = 0.17697773
# Iteration 33, loss = 0.17388287
# Iteration 34, loss = 0.17061385
# Iteration 35, loss = 0.16764138
# Iteration 36, loss = 0.16435170
# Iteration 37, loss = 0.16154205
# Iteration 38, loss = 0.15858442
# Iteration 39, loss = 0.15593599
# Iteration 40, loss = 0.15318287
# Iteration 41, loss = 0.15090569
# Iteration 42, loss = 0.14820609
# Iteration 43, loss = 0.14553487
# Iteration 44, loss = 0.14316529
# Iteration 45, loss = 0.14078106
# Iteration 46, loss = 0.13851606
# Iteration 47, loss = 0.13658341
# Iteration 48, loss = 0.13419712
# Iteration 49, loss = 0.13203857
# Iteration 50, loss = 0.12991035
# Iteration 51, loss = 0.12807355
# Iteration 52, loss = 0.12596543
# Iteration 53, loss = 0.12403138
# Iteration 54, loss = 0.12193970
# Iteration 55, loss = 0.12033762
# Iteration 56, loss = 0.11845686
# Iteration 57, loss = 0.11647676
# Iteration 58, loss = 0.11497019
# Iteration 59, loss = 0.11296868
# Iteration 60, loss = 0.11117366
# Iteration 61, loss = 0.10971154
# Iteration 62, loss = 0.10820698
# Iteration 63, loss = 0.10656064
# Iteration 64, loss = 0.10489155
# Iteration 65, loss = 0.10356995
# Iteration 66, loss = 0.10212866
# Iteration 67, loss = 0.10045153
# Iteration 68, loss = 0.09916178
# Iteration 69, loss = 0.09781437
# Iteration 70, loss = 0.09650770
# Iteration 71, loss = 0.09516397
# Iteration 72, loss = 0.09389258
# Iteration 73, loss = 0.09259651
# Iteration 74, loss = 0.09120652
# Iteration 75, loss = 0.09005945
# Iteration 76, loss = 0.08863820
# Iteration 77, loss = 0.08760251
# Iteration 78, loss = 0.08661590
# Iteration 79, loss = 0.08528046
# Iteration 80, loss = 0.08416324
# Iteration 81, loss = 0.08316013
# Iteration 82, loss = 0.08198692
# Iteration 83, loss = 0.08089442
# Iteration 84, loss = 0.07998836
# Iteration 85, loss = 0.07875901
# Iteration 86, loss = 0.07770355
# Iteration 87, loss = 0.07686519
# Iteration 88, loss = 0.07604262
# Iteration 89, loss = 0.07493956
# Iteration 90, loss = 0.07400942
# Iteration 91, loss = 0.07298348
# Iteration 92, loss = 0.07234635
# Iteration 93, loss = 0.07132353
# Iteration 94, loss = 0.07035112
# Iteration 95, loss = 0.06934075
# Iteration 96, loss = 0.06853730
# Iteration 97, loss = 0.06791280
# Iteration 98, loss = 0.06717785
# Iteration 99, loss = 0.06611130
# Iteration 100, loss = 0.06523877
# Iteration 101, loss = 0.06472884
# Iteration 102, loss = 0.06381494
# Iteration 103, loss = 0.06297090
# Iteration 104, loss = 0.06223470
# Iteration 105, loss = 0.06163812
# Iteration 106, loss = 0.06092196
# Iteration 107, loss = 0.06013386
# Iteration 108, loss = 0.05940306
# Iteration 109, loss = 0.05882822
# Iteration 110, loss = 0.05805978
# Iteration 111, loss = 0.05732482
# Iteration 112, loss = 0.05664640
# Iteration 113, loss = 0.05607253
# Iteration 114, loss = 0.05531396
# Iteration 115, loss = 0.05479666
# Iteration 116, loss = 0.05405425
# Iteration 117, loss = 0.05336046
# Iteration 118, loss = 0.05296314
# Iteration 119, loss = 0.05215567
# Iteration 120, loss = 0.05168115
# Iteration 121, loss = 0.05118641
# Iteration 122, loss = 0.05046439
# Iteration 123, loss = 0.04989070
# Iteration 124, loss = 0.04924706
# Iteration 125, loss = 0.04879246
# Iteration 126, loss = 0.04826412
# Iteration 127, loss = 0.04761194
# Iteration 128, loss = 0.04706206
# Iteration 129, loss = 0.04657674
# Iteration 130, loss = 0.04609955
# Iteration 131, loss = 0.04554874
# Iteration 132, loss = 0.04500513
# Iteration 133, loss = 0.04457049
# Iteration 134, loss = 0.04400986
# Iteration 135, loss = 0.04355289
# Iteration 136, loss = 0.04308590
# Iteration 137, loss = 0.04255403
# Iteration 138, loss = 0.04208241
# Iteration 139, loss = 0.04168958
# Iteration 140, loss = 0.04115529
# Iteration 141, loss = 0.04069540
# Iteration 142, loss = 0.04035330
# Iteration 143, loss = 0.03983092
# Iteration 144, loss = 0.03944604
# Iteration 145, loss = 0.03890254
# Iteration 146, loss = 0.03860072
# Iteration 147, loss = 0.03807469
# Iteration 148, loss = 0.03767147
# Iteration 149, loss = 0.03726628
# Iteration 150, loss = 0.03683373
# Iteration 151, loss = 0.03629775
# Iteration 152, loss = 0.03611138
# Iteration 153, loss = 0.03567949
# Iteration 154, loss = 0.03520159
# Iteration 155, loss = 0.03491033
# Iteration 156, loss = 0.03459524
# Iteration 157, loss = 0.03416839
# Iteration 158, loss = 0.03378168
# Iteration 159, loss = 0.03348183
# Iteration 160, loss = 0.03307564
# Iteration 161, loss = 0.03265706
# Iteration 162, loss = 0.03231637
# Iteration 163, loss = 0.03201185
# Iteration 164, loss = 0.03162968
# Iteration 165, loss = 0.03127650
# Iteration 166, loss = 0.03098162
# Iteration 167, loss = 0.03064750
# Iteration 168, loss = 0.03026660
# Iteration 169, loss = 0.02991015
# Iteration 170, loss = 0.02974571
# Iteration 171, loss = 0.02929689
# Iteration 172, loss = 0.02909120
# Iteration 173, loss = 0.02852861
# Iteration 174, loss = 0.02842031
# Iteration 175, loss = 0.02810385
# Iteration 176, loss = 0.02787756
# Iteration 177, loss = 0.02754175
# Iteration 178, loss = 0.02739234
# Iteration 179, loss = 0.02698969
# Iteration 180, loss = 0.02674541
# Iteration 181, loss = 0.02644530
# Iteration 182, loss = 0.02609907
# Iteration 183, loss = 0.02583181
# Iteration 184, loss = 0.02559227
# Iteration 185, loss = 0.02533751
# Iteration 186, loss = 0.02514508
# Iteration 187, loss = 0.02482937
# Iteration 188, loss = 0.02457311
# Iteration 189, loss = 0.02431517
# Iteration 190, loss = 0.02407485
# Iteration 191, loss = 0.02386479
# Iteration 192, loss = 0.02356591
# Iteration 193, loss = 0.02328534
# Iteration 194, loss = 0.02304623
# Iteration 195, loss = 0.02290184
# Iteration 196, loss = 0.02265117
# Iteration 197, loss = 0.02236289
# Iteration 198, loss = 0.02215956
# Iteration 199, loss = 0.02197748
# Iteration 200, loss = 0.02171689
# Iteration 201, loss = 0.02145349
# Iteration 202, loss = 0.02135095
# Iteration 203, loss = 0.02106848
# Iteration 204, loss = 0.02079953
# Iteration 205, loss = 0.02065337
# Iteration 206, loss = 0.02037254
# Iteration 207, loss = 0.02029332
# Iteration 208, loss = 0.02007169
# Iteration 209, loss = 0.01981940
# Iteration 210, loss = 0.01964124
# Iteration 211, loss = 0.01936092
# Iteration 212, loss = 0.01920908
# Iteration 213, loss = 0.01904490
# Iteration 214, loss = 0.01890524
# Iteration 215, loss = 0.01869410
# Iteration 216, loss = 0.01850574
# Iteration 217, loss = 0.01822504
# Iteration 218, loss = 0.01813678
# Iteration 219, loss = 0.01798722
# Iteration 220, loss = 0.01781003
# Iteration 221, loss = 0.01769415
# Iteration 222, loss = 0.01740480
# Iteration 223, loss = 0.01726004
# Iteration 224, loss = 0.01714938
# Iteration 225, loss = 0.01700818
# Iteration 226, loss = 0.01676446
# Iteration 227, loss = 0.01664117
# Iteration 228, loss = 0.01650730
# Iteration 229, loss = 0.01630222
# Iteration 230, loss = 0.01616112
# Iteration 231, loss = 0.01605045
# Iteration 232, loss = 0.01586318
# Iteration 233, loss = 0.01574525
# Iteration 234, loss = 0.01557225
# Iteration 235, loss = 0.01546415
# Iteration 236, loss = 0.01533659
# Iteration 237, loss = 0.01509618
# Iteration 238, loss = 0.01503666
# Iteration 239, loss = 0.01484905
# Iteration 240, loss = 0.01473687
# Iteration 241, loss = 0.01461224
# Iteration 242, loss = 0.01447465
# Iteration 243, loss = 0.01442628
# Iteration 244, loss = 0.01421959
# Iteration 245, loss = 0.01409317
# Iteration 246, loss = 0.01398256
# Iteration 247, loss = 0.01381564
# Iteration 248, loss = 0.01367427
# Iteration 249, loss = 0.01357992
# Iteration 250, loss = 0.01348051
# Iteration 251, loss = 0.01331208
# Iteration 252, loss = 0.01317266
# Iteration 253, loss = 0.01311863
# Iteration 254, loss = 0.01297138
# Iteration 255, loss = 0.01284862
# Iteration 256, loss = 0.01275998
# Iteration 257, loss = 0.01267529
# Iteration 258, loss = 0.01251720
# Iteration 259, loss = 0.01242266
# Iteration 260, loss = 0.01232962
# Iteration 261, loss = 0.01222192
# Iteration 262, loss = 0.01210439
# Iteration 263, loss = 0.01203294
# Iteration 264, loss = 0.01191566
# Iteration 265, loss = 0.01180816
# Iteration 266, loss = 0.01169748
# Iteration 267, loss = 0.01160710
# Iteration 268, loss = 0.01151243
# Iteration 269, loss = 0.01141043
# Iteration 270, loss = 0.01137027
# Iteration 271, loss = 0.01122261
# Iteration 272, loss = 0.01110958
# Iteration 273, loss = 0.01104244
# Iteration 274, loss = 0.01093385
# Iteration 275, loss = 0.01083673
# Iteration 276, loss = 0.01074716
# Iteration 277, loss = 0.01066675
# Iteration 278, loss = 0.01058708
# Iteration 279, loss = 0.01049894
# Iteration 280, loss = 0.01038213
# Iteration 281, loss = 0.01034754
# Iteration 282, loss = 0.01024330
# Iteration 283, loss = 0.01016956
# Iteration 284, loss = 0.01010463
# Iteration 285, loss = 0.00997606
# Iteration 286, loss = 0.00994598
# Iteration 287, loss = 0.00987673
# Iteration 288, loss = 0.00978660
# Iteration 289, loss = 0.00969805
# Iteration 290, loss = 0.00958393
# Iteration 291, loss = 0.00952807
# Iteration 292, loss = 0.00945653
# Iteration 293, loss = 0.00939249
# Iteration 294, loss = 0.00933720
# Iteration 295, loss = 0.00923295
# Iteration 296, loss = 0.00920165
# Iteration 297, loss = 0.00908748
# Iteration 298, loss = 0.00904390
# Iteration 299, loss = 0.00896385
# Iteration 300, loss = 0.00891946
# Iteration 301, loss = 0.00883346
# Iteration 302, loss = 0.00876270
# Iteration 303, loss = 0.00871304
# Iteration 304, loss = 0.00861860
# Iteration 305, loss = 0.00858293
# Iteration 306, loss = 0.00850447
# Iteration 307, loss = 0.00844065
# Iteration 308, loss = 0.00836928
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Precisión del modelo: 97.15%

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

data = pd.read_csv('DATA/mnist.csv')

X, Y = data.iloc[:, :-1].values / 255, data.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

mlp = MLPClassifier(hidden_layer_sizes=(256, 128), max_iter=600, activation='relu',
                    solver='sgd', verbose=1, random_state=42,
                    learning_rate_init=0.01, batch_size=8192) #97.43 con batch de 4096

mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo: {accuracy * 100:.2f}%')
# Out:
# Iteration 1, loss = 2.17750587
# Iteration 2, loss = 1.71932801
# Iteration 3, loss = 1.19079662
# Iteration 4, loss = 0.80672486
# Iteration 5, loss = 0.61981841
# Iteration 6, loss = 0.52829654
# Iteration 7, loss = 0.47534998
# Iteration 8, loss = 0.44003636
# Iteration 9, loss = 0.41407601
# Iteration 10, loss = 0.39377178
# Iteration 11, loss = 0.37740387
# Iteration 12, loss = 0.36380967
# Iteration 13, loss = 0.35229444
# Iteration 14, loss = 0.34205594
# Iteration 15, loss = 0.33307115
# Iteration 16, loss = 0.32518309
# Iteration 17, loss = 0.31742406
# Iteration 18, loss = 0.31079061
# Iteration 19, loss = 0.30451940
# Iteration 20, loss = 0.29864319
# Iteration 21, loss = 0.29315283
# Iteration 22, loss = 0.28823171
# Iteration 23, loss = 0.28329656
# Iteration 24, loss = 0.27874912
# Iteration 25, loss = 0.27452844
# Iteration 26, loss = 0.27036763
# Iteration 27, loss = 0.26639884
# Iteration 28, loss = 0.26243487
# Iteration 29, loss = 0.25893600
# Iteration 30, loss = 0.25555972
# Iteration 31, loss = 0.25190119
# Iteration 32, loss = 0.24867130
# Iteration 33, loss = 0.24525702
# Iteration 34, loss = 0.24226118
# Iteration 35, loss = 0.23907592
# Iteration 36, loss = 0.23622199
# Iteration 37, loss = 0.23353072
# Iteration 38, loss = 0.23049948
# Iteration 39, loss = 0.22789753
# Iteration 40, loss = 0.22537355
# Iteration 41, loss = 0.22295242
# Iteration 42, loss = 0.22048144
# Iteration 43, loss = 0.21772649
# Iteration 44, loss = 0.21544711
# Iteration 45, loss = 0.21295849
# Iteration 46, loss = 0.21082981
# Iteration 47, loss = 0.20865925
# Iteration 48, loss = 0.20640660
# Iteration 49, loss = 0.20418717
# Iteration 50, loss = 0.20201352
# Iteration 51, loss = 0.20000956
# Iteration 52, loss = 0.19802438
# Iteration 53, loss = 0.19601943
# Iteration 54, loss = 0.19418551
# Iteration 55, loss = 0.19236899
# Iteration 56, loss = 0.19043442
# Iteration 57, loss = 0.18865569
# Iteration 58, loss = 0.18696445
# Iteration 59, loss = 0.18498502
# Iteration 60, loss = 0.18333609
# Iteration 61, loss = 0.18169909
# Iteration 62, loss = 0.18005632
# Iteration 63, loss = 0.17829592
# Iteration 64, loss = 0.17666827
# Iteration 65, loss = 0.17506045
# Iteration 66, loss = 0.17353409
# Iteration 67, loss = 0.17210821
# Iteration 68, loss = 0.17050904
# Iteration 69, loss = 0.16903251
# Iteration 70, loss = 0.16762943
# Iteration 71, loss = 0.16616040
# Iteration 72, loss = 0.16479093
# Iteration 73, loss = 0.16342310
# Iteration 74, loss = 0.16200764
# Iteration 75, loss = 0.16069495
# Iteration 76, loss = 0.15946107
# Iteration 77, loss = 0.15800804
# Iteration 78, loss = 0.15697189
# Iteration 79, loss = 0.15563913
# Iteration 80, loss = 0.15445536
# Iteration 81, loss = 0.15313293
# Iteration 82, loss = 0.15198585
# Iteration 83, loss = 0.15060442
# Iteration 84, loss = 0.14953085
# Iteration 85, loss = 0.14834260
# Iteration 86, loss = 0.14716286
# Iteration 87, loss = 0.14614576
# Iteration 88, loss = 0.14505431
# Iteration 89, loss = 0.14397770
# Iteration 90, loss = 0.14288769
# Iteration 91, loss = 0.14175724
# Iteration 92, loss = 0.14063494
# Iteration 93, loss = 0.13969303
# Iteration 94, loss = 0.13876101
# Iteration 95, loss = 0.13781803
# Iteration 96, loss = 0.13661253
# Iteration 97, loss = 0.13567315
# Iteration 98, loss = 0.13460429
# Iteration 99, loss = 0.13378943
# Iteration 100, loss = 0.13279414
# Iteration 101, loss = 0.13188760
# Iteration 102, loss = 0.13092371
# Iteration 103, loss = 0.12996478
# Iteration 104, loss = 0.12908230
# Iteration 105, loss = 0.12816649
# Iteration 106, loss = 0.12721086
# Iteration 107, loss = 0.12642222
# Iteration 108, loss = 0.12559356
# Iteration 109, loss = 0.12479271
# Iteration 110, loss = 0.12382474
# Iteration 111, loss = 0.12316747
# Iteration 112, loss = 0.12231518
# Iteration 113, loss = 0.12139190
# Iteration 114, loss = 0.12056260
# Iteration 115, loss = 0.11977638
# Iteration 116, loss = 0.11897045
# Iteration 117, loss = 0.11816251
# Iteration 118, loss = 0.11739704
# Iteration 119, loss = 0.11661951
# Iteration 120, loss = 0.11582460
# Iteration 121, loss = 0.11514668
# Iteration 122, loss = 0.11438482
# Iteration 123, loss = 0.11361950
# Iteration 124, loss = 0.11290045
# Iteration 125, loss = 0.11218630
# Iteration 126, loss = 0.11149363
# Iteration 127, loss = 0.11078431
# Iteration 128, loss = 0.11012269
# Iteration 129, loss = 0.10939132
# Iteration 130, loss = 0.10870213
# Iteration 131, loss = 0.10796475
# Iteration 132, loss = 0.10736027
# Iteration 133, loss = 0.10669450
# Iteration 134, loss = 0.10606459
# Iteration 135, loss = 0.10538033
# Iteration 136, loss = 0.10465800
# Iteration 137, loss = 0.10395878
# Iteration 138, loss = 0.10331345
# Iteration 139, loss = 0.10286738
# Iteration 140, loss = 0.10210839
# Iteration 141, loss = 0.10152200
# Iteration 142, loss = 0.10087880
# Iteration 143, loss = 0.10025982
# Iteration 144, loss = 0.09978341
# Iteration 145, loss = 0.09908719
# Iteration 146, loss = 0.09858237
# Iteration 147, loss = 0.09784922
# Iteration 148, loss = 0.09735732
# Iteration 149, loss = 0.09674659
# Iteration 150, loss = 0.09622359
# Iteration 151, loss = 0.09551573
# Iteration 152, loss = 0.09521453
# Iteration 153, loss = 0.09447626
# Iteration 154, loss = 0.09395081
# Iteration 155, loss = 0.09343183
# Iteration 156, loss = 0.09283044
# Iteration 157, loss = 0.09224411
# Iteration 158, loss = 0.09166285
# Iteration 159, loss = 0.09116386
# Iteration 160, loss = 0.09071513
# Iteration 161, loss = 0.09012568
# Iteration 162, loss = 0.08961190
# Iteration 163, loss = 0.08913671
# Iteration 164, loss = 0.08851116
# Iteration 165, loss = 0.08810689
# Iteration 166, loss = 0.08757455
# Iteration 167, loss = 0.08702410
# Iteration 168, loss = 0.08657777
# Iteration 169, loss = 0.08604429
# Iteration 170, loss = 0.08560321
# Iteration 171, loss = 0.08516985
# Iteration 172, loss = 0.08472825
# Iteration 173, loss = 0.08419125
# Iteration 174, loss = 0.08369390
# Iteration 175, loss = 0.08322061
# Iteration 176, loss = 0.08274216
# Iteration 177, loss = 0.08229214
# Iteration 178, loss = 0.08195692
# Iteration 179, loss = 0.08136067
# Iteration 180, loss = 0.08095455
# Iteration 181, loss = 0.08055945
# Iteration 182, loss = 0.08002142
# Iteration 183, loss = 0.07958201
# Iteration 184, loss = 0.07915115
# Iteration 185, loss = 0.07880512
# Iteration 186, loss = 0.07841900
# Iteration 187, loss = 0.07798401
# Iteration 188, loss = 0.07740734
# Iteration 189, loss = 0.07705761
# Iteration 190, loss = 0.07659007
# Iteration 191, loss = 0.07627016
# Iteration 192, loss = 0.07577303
# Iteration 193, loss = 0.07536661
# Iteration 194, loss = 0.07508686
# Iteration 195, loss = 0.07461642
# Iteration 196, loss = 0.07418175
# Iteration 197, loss = 0.07377963
# Iteration 198, loss = 0.07344112
# Iteration 199, loss = 0.07299113
# Iteration 200, loss = 0.07257060
# Iteration 201, loss = 0.07221096
# Iteration 202, loss = 0.07178592
# Iteration 203, loss = 0.07140260
# Iteration 204, loss = 0.07102706
# Iteration 205, loss = 0.07065418
# Iteration 206, loss = 0.07019446
# Iteration 207, loss = 0.07003595
# Iteration 208, loss = 0.06950342
# Iteration 209, loss = 0.06913507
# Iteration 210, loss = 0.06876594
# Iteration 211, loss = 0.06848419
# Iteration 212, loss = 0.06806790
# Iteration 213, loss = 0.06774940
# Iteration 214, loss = 0.06741244
# Iteration 215, loss = 0.06697562
# Iteration 216, loss = 0.06666171
# Iteration 217, loss = 0.06643084
# Iteration 218, loss = 0.06597949
# Iteration 219, loss = 0.06567025
# Iteration 220, loss = 0.06527613
# Iteration 221, loss = 0.06490450
# Iteration 222, loss = 0.06465730
# Iteration 223, loss = 0.06426657
# Iteration 224, loss = 0.06396882
# Iteration 225, loss = 0.06364868
# Iteration 226, loss = 0.06331368
# Iteration 227, loss = 0.06296849
# Iteration 228, loss = 0.06265456
# Iteration 229, loss = 0.06231802
# Iteration 230, loss = 0.06196449
# Iteration 231, loss = 0.06171025
# Iteration 232, loss = 0.06141715
# Iteration 233, loss = 0.06106481
# Iteration 234, loss = 0.06071341
# Iteration 235, loss = 0.06044263
# Iteration 236, loss = 0.06010070
# Iteration 237, loss = 0.05983576
# Iteration 238, loss = 0.05954165
# Iteration 239, loss = 0.05929971
# Iteration 240, loss = 0.05890284
# Iteration 241, loss = 0.05877960
# Iteration 242, loss = 0.05829679
# Iteration 243, loss = 0.05803607
# Iteration 244, loss = 0.05773860
# Iteration 245, loss = 0.05742233
# Iteration 246, loss = 0.05717419
# Iteration 247, loss = 0.05688932
# Iteration 248, loss = 0.05661793
# Iteration 249, loss = 0.05638588
# Iteration 250, loss = 0.05606442
# Iteration 251, loss = 0.05578351
# Iteration 252, loss = 0.05547983
# Iteration 253, loss = 0.05526340
# Iteration 254, loss = 0.05506991
# Iteration 255, loss = 0.05469883
# Iteration 256, loss = 0.05443174
# Iteration 257, loss = 0.05422453
# Iteration 258, loss = 0.05388248
# Iteration 259, loss = 0.05364825
# Iteration 260, loss = 0.05346339
# Iteration 261, loss = 0.05318554
# Iteration 262, loss = 0.05284824
# Iteration 263, loss = 0.05256970
# Iteration 264, loss = 0.05229054
# Iteration 265, loss = 0.05218001
# Iteration 266, loss = 0.05191832
# Iteration 267, loss = 0.05157896
# Iteration 268, loss = 0.05141893
# Iteration 269, loss = 0.05107009
# Iteration 270, loss = 0.05084108
# Iteration 271, loss = 0.05061097
# Iteration 272, loss = 0.05033601
# Iteration 273, loss = 0.05012352
# Iteration 274, loss = 0.04989505
# Iteration 275, loss = 0.04961935
# Iteration 276, loss = 0.04932316
# Iteration 277, loss = 0.04907219
# Iteration 278, loss = 0.04881020
# Iteration 279, loss = 0.04864432
# Iteration 280, loss = 0.04837743
# Iteration 281, loss = 0.04822895
# Iteration 282, loss = 0.04805120
# Iteration 283, loss = 0.04780084
# Iteration 284, loss = 0.04754480
# Iteration 285, loss = 0.04730557
# Iteration 286, loss = 0.04703830
# Iteration 287, loss = 0.04687096
# Iteration 288, loss = 0.04658727
# Iteration 289, loss = 0.04635520
# Iteration 290, loss = 0.04614945
# Iteration 291, loss = 0.04592462
# Iteration 292, loss = 0.04579330
# Iteration 293, loss = 0.04553540
# Iteration 294, loss = 0.04529995
# Iteration 295, loss = 0.04512042
# Iteration 296, loss = 0.04499366
# Iteration 297, loss = 0.04474970
# Iteration 298, loss = 0.04441059
# Iteration 299, loss = 0.04418294
# Iteration 300, loss = 0.04399562
# Iteration 301, loss = 0.04384488
# Iteration 302, loss = 0.04356871
# Iteration 303, loss = 0.04340670
# Iteration 304, loss = 0.04320132
# Iteration 305, loss = 0.04307030
# Iteration 306, loss = 0.04287445
# Iteration 307, loss = 0.04266326
# Iteration 308, loss = 0.04240098
# Iteration 309, loss = 0.04223740
# Iteration 310, loss = 0.04205164
# Iteration 311, loss = 0.04178309
# Iteration 312, loss = 0.04160882
# Iteration 313, loss = 0.04143077
# Iteration 314, loss = 0.04123624
# Iteration 315, loss = 0.04105197
# Iteration 316, loss = 0.04082246
# Iteration 317, loss = 0.04073961
# Iteration 318, loss = 0.04049357
# Iteration 319, loss = 0.04037443
# Iteration 320, loss = 0.04007039
# Iteration 321, loss = 0.03999973
# Iteration 322, loss = 0.03972383
# Iteration 323, loss = 0.03948939
# Iteration 324, loss = 0.03936675
# Iteration 325, loss = 0.03918889
# Iteration 326, loss = 0.03905588
# Iteration 327, loss = 0.03883236
# Iteration 328, loss = 0.03868003
# Iteration 329, loss = 0.03850069
# Iteration 330, loss = 0.03829102
# Iteration 331, loss = 0.03811935
# Iteration 332, loss = 0.03792476
# Iteration 333, loss = 0.03775550
# Iteration 334, loss = 0.03754827
# Iteration 335, loss = 0.03738870
# Iteration 336, loss = 0.03724338
# Iteration 337, loss = 0.03710169
# Iteration 338, loss = 0.03686235
# Iteration 339, loss = 0.03671330
# Iteration 340, loss = 0.03661344
# Iteration 341, loss = 0.03637766
# Iteration 342, loss = 0.03625249
# Iteration 343, loss = 0.03606049
# Iteration 344, loss = 0.03600242
# Iteration 345, loss = 0.03572029
# Iteration 346, loss = 0.03558627
# Iteration 347, loss = 0.03545391
# Iteration 348, loss = 0.03527316
# Iteration 349, loss = 0.03509411
# Iteration 350, loss = 0.03490523
# Iteration 351, loss = 0.03480262
# Iteration 352, loss = 0.03462156
# Iteration 353, loss = 0.03445606
# Iteration 354, loss = 0.03435529
# Iteration 355, loss = 0.03416956
# Iteration 356, loss = 0.03399227
# Iteration 357, loss = 0.03391465
# Iteration 358, loss = 0.03384006
# Iteration 359, loss = 0.03352234
# Iteration 360, loss = 0.03343402
# Iteration 361, loss = 0.03324731
# Iteration 362, loss = 0.03311725
# Iteration 363, loss = 0.03295841
# Iteration 364, loss = 0.03279397
# Iteration 365, loss = 0.03271231
# Iteration 366, loss = 0.03246923
# Iteration 367, loss = 0.03238217
# Iteration 368, loss = 0.03222375
# Iteration 369, loss = 0.03213552
# Iteration 370, loss = 0.03192566
# Iteration 371, loss = 0.03179122
# Iteration 372, loss = 0.03170689
# Iteration 373, loss = 0.03157409
# Iteration 374, loss = 0.03137044
# Iteration 375, loss = 0.03124139
# Iteration 376, loss = 0.03112616
# Iteration 377, loss = 0.03096563
# Iteration 378, loss = 0.03084229
# Iteration 379, loss = 0.03075898
# Iteration 380, loss = 0.03064717
# Iteration 381, loss = 0.03048768
# Iteration 382, loss = 0.03027444
# Iteration 383, loss = 0.03018152
# Iteration 384, loss = 0.03003519
# Iteration 385, loss = 0.02990791
# Iteration 386, loss = 0.02976253
# Iteration 387, loss = 0.02964067
# Iteration 388, loss = 0.02950193
# Iteration 389, loss = 0.02935307
# Iteration 390, loss = 0.02922552
# Iteration 391, loss = 0.02910767
# Iteration 392, loss = 0.02898623
# Iteration 393, loss = 0.02885871
# Iteration 394, loss = 0.02873752
# Iteration 395, loss = 0.02862444
# Iteration 396, loss = 0.02852967
# Iteration 397, loss = 0.02837916
# Iteration 398, loss = 0.02820800
# Iteration 399, loss = 0.02810143
# Iteration 400, loss = 0.02795768
# Iteration 401, loss = 0.02785450
# Iteration 402, loss = 0.02772845
# Iteration 403, loss = 0.02768429
# Iteration 404, loss = 0.02755706
# Iteration 405, loss = 0.02739064
# Iteration 406, loss = 0.02724749
# Iteration 407, loss = 0.02717482
# Iteration 408, loss = 0.02699716
# Iteration 409, loss = 0.02697612
# Iteration 410, loss = 0.02682072
# Iteration 411, loss = 0.02664521
# Iteration 412, loss = 0.02653005
# Iteration 413, loss = 0.02643950
# Iteration 414, loss = 0.02634760
# Iteration 415, loss = 0.02620398
# Iteration 416, loss = 0.02614093
# Iteration 417, loss = 0.02599777
# Iteration 418, loss = 0.02592049
# Iteration 419, loss = 0.02573383
# Iteration 420, loss = 0.02568276
# Iteration 421, loss = 0.02557005
# Iteration 422, loss = 0.02543044
# Iteration 423, loss = 0.02529369
# Iteration 424, loss = 0.02519185
# Iteration 425, loss = 0.02511078
# Iteration 426, loss = 0.02498975
# Iteration 427, loss = 0.02489785
# Iteration 428, loss = 0.02477905
# Iteration 429, loss = 0.02469292
# Iteration 430, loss = 0.02454137
# Iteration 431, loss = 0.02443964
# Iteration 432, loss = 0.02435920
# Iteration 433, loss = 0.02424170
# Iteration 434, loss = 0.02413575
# Iteration 435, loss = 0.02403129
# Iteration 436, loss = 0.02394383
# Iteration 437, loss = 0.02383677
# Iteration 438, loss = 0.02375960
# Iteration 439, loss = 0.02367305
# Iteration 440, loss = 0.02357844
# Iteration 441, loss = 0.02344716
# Iteration 442, loss = 0.02340484
# Iteration 443, loss = 0.02325790
# Iteration 444, loss = 0.02314889
# Iteration 445, loss = 0.02308691
# Iteration 446, loss = 0.02295061
# Iteration 447, loss = 0.02284882
# Iteration 448, loss = 0.02275129
# Iteration 449, loss = 0.02266427
# Iteration 450, loss = 0.02256975
# Iteration 451, loss = 0.02246487
# Iteration 452, loss = 0.02241419
# Iteration 453, loss = 0.02228991
# Iteration 454, loss = 0.02220665
# Iteration 455, loss = 0.02210021
# Iteration 456, loss = 0.02199384
# Iteration 457, loss = 0.02189093
# Iteration 458, loss = 0.02182697
# Iteration 459, loss = 0.02171954
# Iteration 460, loss = 0.02162882
# Iteration 461, loss = 0.02153981
# Iteration 462, loss = 0.02143099
# Iteration 463, loss = 0.02142463
# Iteration 464, loss = 0.02126581
# Iteration 465, loss = 0.02117140
# Iteration 466, loss = 0.02114318
# Iteration 467, loss = 0.02098370
# Iteration 468, loss = 0.02093588
# Iteration 469, loss = 0.02081314
# Iteration 470, loss = 0.02073586
# Iteration 471, loss = 0.02066119
# Iteration 472, loss = 0.02056581
# Iteration 473, loss = 0.02047225
# Iteration 474, loss = 0.02039937
# Iteration 475, loss = 0.02035192
# Iteration 476, loss = 0.02024977
# Iteration 477, loss = 0.02015642
# Iteration 478, loss = 0.02009872
# Iteration 479, loss = 0.01999902
# Iteration 480, loss = 0.01990572
# Iteration 481, loss = 0.01983009
# Iteration 482, loss = 0.01973466
# Iteration 483, loss = 0.01967705
# Iteration 484, loss = 0.01963220
# Iteration 485, loss = 0.01951938
# Iteration 486, loss = 0.01943868
# Iteration 487, loss = 0.01933655
# Iteration 488, loss = 0.01927599
# Iteration 489, loss = 0.01916385
# Iteration 490, loss = 0.01911330
# Iteration 491, loss = 0.01901411
# Iteration 492, loss = 0.01896932
# Iteration 493, loss = 0.01888940
# Iteration 494, loss = 0.01884518
# Iteration 495, loss = 0.01871523
# Iteration 496, loss = 0.01868808
# Iteration 497, loss = 0.01861290
# Iteration 498, loss = 0.01851562
# Iteration 499, loss = 0.01841912
# Iteration 500, loss = 0.01837996
# Iteration 501, loss = 0.01829700
# Iteration 502, loss = 0.01823280
# Iteration 503, loss = 0.01815119
# Iteration 504, loss = 0.01806836
# Iteration 505, loss = 0.01800091
# Iteration 506, loss = 0.01793475
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Precisión del modelo: 97.43%

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Función para preprocesar una imagen (28x28 píxeles, escala de grises)
def preprocesar_imagen(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  # Cargar la imagen en escala de grises, saca los rdb si tiene
    img_resized = cv2.resize(img, (28, 28))  # redimenciono 28x28
    img_resized = img_resized / 255.0  # Normalizo de 0-1
    img_resized = img_resized.flatten()  # Aplanar la imagen a un vector de 784 elementos
    return img_resized

for i in range(9):
    path_imagen = f'digits/digitB{i}.png'
    imagen_procesada = preprocesar_imagen(path_imagen)

    imagen_procesada = imagen_procesada.reshape(1, -1)  # Lo cambio de (784,) a (1, 784) que es la forma correcta

    prediccion = mlp.predict(imagen_procesada)
    print(f'The image is probably a: {prediccion}')

    # La vuelvo a poner en 28x28 para que el humano vea como lo "ve" la maquina
    plt.imshow(imagen_procesada.reshape(28, 28), cmap='gray')
    plt.title(f'Prediction: {prediccion[0]}')
    plt.show()
# Out:
# The image is probably a: [0]
# The image is probably a: [1]
# The image is probably a: [2]
# The image is probably a: [3]
# The image is probably a: [4]
# The image is probably a: [5]
# The image is probably a: [6]
# The image is probably a: [7]
# The image is probably a: [8]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Crear una ventana para dibujar
drawing = False  # Controla el estado de dibujo
last_point = None  # Guarda el último punto donde se dibujó

def mouse_callback(event, x, y, flags, param):
    global drawing, last_point
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        last_point = (x, y)
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            cv2.line(canvas, last_point, (x, y), (255, 255, 255), 30)  # Dibuja con un grosor de 30 todo blanco
            last_point = (x, y)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        last_point = None

# Crear una imagen en negro de 200x200 píxeles
canvas = np.zeros((200, 200), dtype=np.uint8) # uint8 es de 0 a 255 (1 byte)

# Crear una ventana y registrar el callback del mouse
cv2.namedWindow("ventana") # defino la ventana
cv2.setMouseCallback("ventana", mouse_callback) # asocio la ventana con la funcion

print("Draw a number and press 'Enter' to predict it.")

while True:
    cv2.imshow("ventana", canvas) # muestro la ventana
    key = cv2.waitKey(1) & 0xFF # verifica si en ese 1 milisegundo presionaste una tecla, y obtiene su código entre 0 y 255 por eso el FF.
    if key == 13:  # Enter key
        break
    elif key == 27:  # Esc key
        canvas.fill(0)  # Limpiar el lienzo

cv2.destroyAllWindows()

# Preprocesar la imagen dibujada
def preprocesar_imagen(img):
    # Redimensionar la imagen a 20x20 
    img_resized = cv2.resize(img, (20, 20))
    
    # Crear un nuevo lienzo de 28x28 píxeles
    img_with_border = np.zeros((28, 28), dtype=np.uint8)
    
    # Pngo la imagen redimensionada en el centro de la nueva imagen
    img_with_border[4:24, 4:24] = img_resized 
    
    img_with_border = img_with_border / 255.0  # Normalizar de 0-1
    img_with_border = img_with_border.flatten()  # Aplanar la imagen a un vector de 784 elementos
    return img_with_border

# Procesar la imagen dibujada
imagen_procesada = preprocesar_imagen(canvas)
imagen_procesada = imagen_procesada.reshape(1, -1)  # Cambiar a la forma correcta (1, 784)

prediccion = mlp.predict(imagen_procesada)

print(f"The image is probably a: {prediccion[0]}")

# Mostrar la imagen
plt.imshow(imagen_procesada.reshape(28, 28), cmap="gray")
plt.title(f"Prediction: {prediccion[0]}")
plt.show()
# Out:
# Draw a number and press 'Enter' to predict it.
# The image is probably a: 8
